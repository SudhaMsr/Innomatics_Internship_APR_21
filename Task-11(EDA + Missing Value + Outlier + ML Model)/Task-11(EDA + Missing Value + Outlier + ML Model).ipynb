# %% [markdown]
# # MISSING VALUE
# Missing Data. Missing data is straightforward to identify. It is more difficult to determine
# whether missing data is bad data or not. For this, one needs to know where a value is
# required, versus where one is optional.

# %% [markdown]
# # OUTLIER
# Outliers. Outliers are those data values that are deemed to be “out-of-range”; that is,
# when compared to other values for the same measure, they are considered implausible.
# (For variables with defined ranges, out of range values would be classified as
# impossible values, versus outliers.) Outlier values may be the hardest category of bad
# data to identify. There are many techniques that can be used to define outliers, both 3
# parametric techniques (which pre-suppose the distributional characteristics of the data)
# and non-parametric techniques (which do not pre-suppose an underlying distribution.)

# %% [markdown]
# # ML MODEL
# ML algorithms, concepts, Maths and coding.
#
# To work with ML code, libraries play a very important role in Python which we will study in details but let see a very brief description of the most important ones :
#
# NumPy (Numerical Python) : It is one of the greatest Scientific and Mathematical computing library for Python. Platforms like Keras, Tensorflow have embedded Numpy operations on Tensors. The feature we are concerned with its power and easy to handle and perform operation on Array.
# Pandas : This package is very useful when it comes to handle data. This makes it very easier to manipulate, aggregate and visualize data.
# MatplotLib : This library facilitates the task of powerful and very simple visualizations.
# There are many more libraries but they have no use right now. So, let’s begin.

# %% [markdown]
# # IMPORT DATA

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('adult (1).csv',na_values='?')

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
#here we have null values with columns workclass = 2799,occupation = 2809,native-country = 857

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data.shape
# Out:
# (48842, 15)

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# # EDA

# %% [markdown]
# ### knowing skewness and kurtosis

# %%
print("skew of age ",data.age.skew())
print("skew of fnlwgt ",data.fnlwgt.skew())
print("skew of educational-num ",data['educational-num'].skew())
print("skew of capital-gain ",data['capital-gain'].skew())
print("skew of capital-loss ",data['capital-loss'].skew())
print("skew of hours-per-week ",data['hours-per-week'].skew())
# Out:
# skew of age  0.5575803166133181
# skew of fnlwgt  1.4388918785218416
# skew of educational-num  -0.3165248566607419
# skew of capital-gain  11.894658996587946
# skew of capital-loss  4.569808857738484
# skew of hours-per-week  0.23874965720275756

# %%
print("skew of age ",data.age.kurtosis())
print("skew of fnlwgt ",data.fnlwgt.kurtosis())
print("skew of educational-num ",data['educational-num'].kurtosis())
print("skew of capital-gain ",data['capital-gain'].kurtosis())
print("skew of capital-loss ",data['capital-loss'].kurtosis())
print("skew of hours-per-week ",data['hours-per-week'].kurtosis())
# Out:
# skew of age  -0.18426874062387766
# skew of fnlwgt  6.05784821246471
# skew of educational-num  0.6257452727879236
# skew of capital-gain  152.69309629828723
# skew of capital-loss  20.01434595465143
# skew of hours-per-week  2.9510590898442954

# %%
sns.distplot(data.fnlwgt)
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Density'>

# %%
# the distribution of fnlwgt column is right skew with value as shown above

# %%
sns.distplot(data['capital-gain'])
# Out:
# <AxesSubplot:xlabel='capital-gain', ylabel='Density'>

# %%
# the distribution of capital-gain column is right skew with highly value of right skewness

# %%
sns.distplot(data['capital-loss'])
# Out:
# <AxesSubplot:xlabel='capital-loss', ylabel='Density'>

# %%
# the distribution of capital-loss column is right skew

# %%
sns.distplot(data['hours-per-week'])
# Out:
# <AxesSubplot:xlabel='hours-per-week', ylabel='Density'>

# %%
# in above distribution of hours-per-week column is like normally distributed and consists outliers

# %%
plt.figure(figsize=[15,4])
sns.countplot(x = 'workclass',data=data)
# Out:
# <AxesSubplot:xlabel='workclass', ylabel='count'>

# %%
# in workclass they are more private in count

# %%
plt.figure(figsize=[15,5])
sns.countplot(x = 'education',data=data)
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
# in education column they are more HS-grad in count

# %%
plt.figure(figsize=[15,5])
sns.countplot(x='marital-status',data=data)
# Out:
# <AxesSubplot:xlabel='marital-status', ylabel='count'>

# %%
# in marital-status column they are more Married-civ-spouse in count

# %%
sns.countplot(x='gender',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
# they are more number of males in gender columns

# %%
sns.countplot(x='income',data=data)
# Out:
# <AxesSubplot:xlabel='income', ylabel='count'>

# %%
# the income <= 50k is more

# %%
sns.histplot(data.fnlwgt)
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Count'>

# %%
sns.histplot(data['educational-num'])
# Out:
# <AxesSubplot:xlabel='educational-num', ylabel='Count'>

# %%
plt.figure(figsize=[10,4])
sns.histplot(data['relationship'])
# Out:
# <AxesSubplot:xlabel='relationship', ylabel='Count'>

# %%
# by seeing the histplot, Husband has more in count and have right skewed data

# %%
sns.pairplot(data,diag_kind='kde');

# %%
data.corr()
# Out:
#                       age    fnlwgt  educational-num  capital-gain  \
# age              1.000000 -0.076628         0.030940      0.077229
# fnlwgt          -0.076628  1.000000        -0.038761     -0.003706
# educational-num  0.030940 -0.038761         1.000000      0.125146
# capital-gain     0.077229 -0.003706         0.125146      1.000000
# capital-loss     0.056944 -0.004366         0.080972     -0.031441
# hours-per-week   0.071558 -0.013519         0.143689      0.082157
#
#                  capital-loss  hours-per-week
# age                  0.056944        0.071558
# fnlwgt              -0.004366       -0.013519
# educational-num      0.080972        0.143689
# capital-gain        -0.031441        0.082157
# capital-loss         1.000000        0.054467
# hours-per-week       0.054467        1.000000

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# here we are seeing the correlation of data,some are negitivly correlated and some are positivly correlated

# %%
plt.scatter(data.age,data.fnlwgt)

# %%
# from above plot age and fnlwgt are week negitivly corelated to each other

# %%
plt.scatter(data.age,data['educational-num'])

# %%
#  from above plot no correlated between age and educational-num

# %%
plt.hexbin(data.age,data.fnlwgt)

# %%
# when you have a lot of data points, Without overlapping of the points

# %%
sns.barplot(y = data.age, x = data.gender)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
# here we can say that male age is more when compare to female age

# %%
sns.barplot(y = data.age, hue= data.gender,x=data.relationship)
# Out:
# <AxesSubplot:xlabel='relationship', ylabel='age'>

# %%
sns.distplot(data[data['gender']=='Male']['hours-per-week'],color='r',label=0)
sns.distplot(data[data['gender']=='Female']['hours-per-week'],color='g',label=1)
plt.legend()
plt.show()

# %%
plt.figure(figsize=[10,5])
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
# fnlwgt column we have more outliers

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
# here we can see that both male and female has similar distribution

# %%
data['native-country'].value_counts()
# Out:
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Nicaragua                        49
# Greece                           49
# ...

# %%
pd.crosstab(data['workclass'], data['gender'])
# Out:
# gender            Female   Male
# workclass
# Federal-gov          452    980
# Local-gov           1258   1878
# Never-worked           3      7
# Private            11599  22307
# Self-emp-inc         211   1484
# Self-emp-not-inc     629   3233
# State-gov            763   1218
# Without-pay            7     14

# %%
# from above crosstab we can observe that Males are more in number when compare Females in every workclass

# %% [markdown]
# ## Handling  with missing values and Outliers

# %%
data.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
# they are many ways to fill missing values instead of dropping ,we  filled the data with bfill 
data.fillna(method='bfill',inplace=True)

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
# ## Using Z-score method
# The intuition behind Z-score is to describe any data point by finding their relationship with the Standard Deviation and Mean of the group of data points. Z-score is finding the distribution of data where mean is 0 and standard deviation is 1 i.e. normal distribution.
#
# In most of the cases a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(data[['age','fnlwgt','educational-num','hours-per-week']]))

# %%
data.shape, z.shape
# Out:
# ((48842, 15), (48842, 4))

# %%
z
# Out:
# array([[0.99512893, 0.35167453, 1.19725891, 0.03408696],
#        [0.04694151, 0.94552415, 0.41933527, 0.77292975],
#        [0.77631645, 1.3947231 , 0.74755018, 0.03408696],
#        ...,
#        [1.41180837, 0.35751025, 0.41933527, 0.03408696],
#        [1.21394141, 0.11198424, 0.41933527, 1.64812038],
#        [0.97418341, 0.93049361, 0.41933527, 0.03408696]])

# %%
threshold = 3

result = np.where(z > 3)
result
# Out:
# (array([   25,   157,   188, ..., 48806, 48806, 48812], dtype=int64),
#  array([3, 1, 1, ..., 0, 3, 3], dtype=int64))

# %%
len(result[0]), len(result[1])
# Out:
# (1703, 1703)

# %%
outlier_df = pd.DataFrame(data=result[0], columns=['ROWNUM'])

outlier_df['COLNUM'] = result[1]
outlier_df.head()
# Out:
#    ROWNUM  COLNUM
# 0      25       3
# 1     157       1
# 2     188       1
# 3     234       0
# 4     288       1

# %%
outlier_df.COLNUM.value_counts()
# Out:
# 3    681
# 1    506
# 2    330
# 0    186
# Name: COLNUM, dtype: int64

# %%
columns = data.columns
columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
outlier_df['COLNAME'] = columns[outlier_df.COLNUM]
outlier_df
# Out:
#       ROWNUM  COLNUM    COLNAME
# 0         25       3  education
# 1        157       1  workclass
# 2        188       1  workclass
# 3        234       0        age
# 4        288       1  workclass
# ...      ...     ...        ...
# 1698   48775       3  education
# 1699   48792       1  workclass
# 1700   48806       0        age
# 1701   48806       3  education
# 1702   48812       3  education
#
# [1703 rows x 3 columns]

# %% [markdown]
# ## IQR score -
#
# Observations below Q1- 1.5 IQR, or those above Q3 + 1.5IQR are defined as outliers.

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)

IQR = Q3 - Q1
print(IQR)
# Out:
# age                    20.0
# fnlwgt             120091.5
# educational-num         3.0
# capital-gain            0.0
# capital-loss            0.0
# hours-per-week          5.0
# dtype: float64

# %%
# outliers seeing by boxplot

# %%
fig, (axes) = plt.subplots(nrows=1, ncols=6, figsize=(20, 5))

sns.boxplot(data=data[['age']],  palette='Set2', ax=axes[0]);
sns.boxplot(data=data[['fnlwgt']]  ,  palette='Set2', ax=axes[1]);
sns.boxplot(data=data[['educational-num']], palette='Set2', ax=axes[2]);
sns.boxplot(data=data[['capital-gain']],  palette='Set2', ax=axes[3]);
sns.boxplot(data=data[['capital-loss']],   palette='Set2', ax=axes[4]);
sns.boxplot(data=data[['hours-per-week']]  ,  palette='Set2', ax=axes[5]);

# %% [markdown]
# ### Treating outlier

# %%
# median imputation for age column
sns.boxplot(data['age'])
plt.title("Box Plot before median imputation")
plt.show()
q1 = data['age'].quantile(0.25)
q3 = data['age'].quantile(0.73)
iqr = q3-q1
Lower_tail = q1 - 1.5 * iqr
Upper_tail = q3 + 1.5 * iqr
med = np.median(data['age'])
for i in data['age']:
    if i > Upper_tail or i < Lower_tail:
            data['age'] = data['age'].replace(i, med)
sns.boxplot(data['age'])
plt.title("Box Plot after median imputation")
plt.show()

# %%
# removing outliers for fnlwgt
Q1=data['fnlwgt'].quantile(0.25)
Q3=data['fnlwgt'].quantile(0.72)
IQR=Q3-Q1
print(Q1)
print(Q3)
print(IQR)
Lower_Whisker = Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR
print(Lower_Whisker, Upper_Whisker)
# Out:
# 117550.5
# 226837.87999999977
# 109287.37999999977
# -46380.56999999966 390768.94999999943

# %%
data = data[(data.fnlwgt>Lower_Whisker) & (data.fnlwgt<Upper_Whisker)]

# %%
data.shape
# Out:
# (46714, 15)

# %%
sns.boxplot(data.fnlwgt)
# Out:
# <AxesSubplot:xlabel='fnlwgt'>

# %%
data = pd.DataFrame(data= data)

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18       Private  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# ##  LABEL ENCODING

# %% [markdown]
# ##### LABEL ENCODING IS USED TO CONVERT INTO CATOGORICAL TO NUMERICAL.

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
data.workclass=enc.fit_transform(data.workclass)
data.education=enc.fit_transform(data.education)
data['marital-status']=enc.fit_transform(data['marital-status'])
data.occupation=enc.fit_transform(data.occupation)
data.relationship=enc.fit_transform(data.relationship)
data.race=enc.fit_transform(data.race)
data.gender=enc.fit_transform(data.gender)
data['native-country']=enc.fit_transform(data['native-country'])
data.income=enc.fit_transform(data.income)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46714 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              46714 non-null  int64
#  1   workclass        46714 non-null  int32
#  2   fnlwgt           46714 non-null  int64
#  3   education        46714 non-null  int32
#  4   educational-num  46714 non-null  int64
#  5   marital-status   46714 non-null  int32
#  6   occupation       46714 non-null  int32
#  7   relationship     46714 non-null  int32
#  8   race             46714 non-null  int32
#  9   gender           46714 non-null  int32
#  10  capital-gain     46714 non-null  int64
#  11  capital-loss     46714 non-null  int64
#  12  hours-per-week   46714 non-null  int64
#  13  native-country   46714 non-null  int32
#  14  income           46714 non-null  int32
# dtypes: int32(9), int64(6)
# memory usage: 4.1 MB

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0   25          3  226802          1                7               4
# 1   38          3   89814         11                9               2
# 2   28          1  336951          7               12               2
# 3   44          3  160323         15               10               2
# 4   18          3  103497         15               10               4
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           6             3     2       1             0             0
# 1           4             0     4       1             0             0
# 2          10             0     4       1             0             0
# 3           6             0     2       1          7688             0
# 4           7             3     4       0             0             0
#
#    hours-per-week  native-country  income
# 0              40              38       0
# ...

# %%
X = data.loc[:, data.columns != 'income']  # independent variables
y = data.loc[:, data.columns == 'income']  # Target variable

# %%
X.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0   25          3  226802          1                7               4
# 1   38          3   89814         11                9               2
# 2   28          1  336951          7               12               2
# 3   44          3  160323         15               10               2
# 4   18          3  103497         15               10               4
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           6             3     2       1             0             0
# 1           4             0     4       1             0             0
# 2          10             0     4       1             0             0
# 3           6             0     2       1          7688             0
# 4           7             3     4       0             0             0
#
#    hours-per-week  native-country
# 0              40              38
# 1              50              38
# ...

# %%
y.head()
# Out:
#    income
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %%
# Create the training and test data set in the ratio of 70:30 respectively. Can be of any ratio...

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=70)

# %%
X_train.shape,X_test.shape
# Out:
# ((32699, 14), (14015, 14))

# %%
X_train.head()
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 9189    43          4   84924         15               10               2
# 41747   33          3   82393         11                9               4
# 16896   39          3  207824         11                9               4
# 39999   50          3  283676         15               10               0
# 19057   26          3  188767          9               13               4
#
#        occupation  relationship  race  gender  capital-gain  capital-loss  \
# 9189           11             0     4       1             0             0
# 41747           2             3     1       1             0             0
# 16896           5             3     4       1             0             0
# 39999           2             1     4       1             0             0
# 19057          11             3     4       1             0             0
#
#        hours-per-week  native-country
# ...

# %% [markdown]
# ###   Training Logistic Regression model to prediction

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=7)

model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=7)

# %%
fea  = X_train.columns

# %%
pd.DataFrame(fea,pd.Series(model.coef_.round(2).ravel()))
# Out:
#                      0
#  0.02              age
# -0.01        workclass
# -0.00           fnlwgt
# -0.01        education
#  0.01  educational-num
# -0.01   marital-status
# -0.01       occupation
# -0.02     relationship
# -0.01             race
#  0.00           gender
#  0.00     capital-gain
#  0.00     capital-loss
#  0.02   hours-per-week
# -0.07   native-country

# %%
y_pred_class=model.predict(X_test)
y_pred_prob=model.predict_proba(X_test)

# %%
y_pred_class.shape,y_test.shape
# Out:
# ((14015,), (14015, 1))

# %%
y_pred_class[:5]
# Out:
# array([0, 0, 0, 1, 0])

# %%
y_pred_prob[:5,:]
# Out:
# array([[0.71073217, 0.28926783],
#        [0.88399169, 0.11600831],
#        [0.85060927, 0.14939073],
#        [0.25548291, 0.74451709],
#        [0.86642063, 0.13357937]])

# %% [markdown]
# <b> Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
## function to get confusion matrix in a proper format
def draw_cm( actual, predicted ):
    cm = confusion_matrix( actual, predicted)
    sns.heatmap(cm, annot=True,  fmt='.0f', xticklabels = [0,1] , yticklabels = [0,1] )
    plt.ylabel('Observed')
    plt.xlabel('Predicted')
    plt.show()

# %%
draw_cm(y_test,y_pred_class);

# %%
from sklearn.metrics import accuracy_score

# %%
log_reg_acc = accuracy_score(y_test,y_pred_class)*100

# %%
log_reg_acc
# Out:
# 78.6942561541206

# %%
from sklearn.metrics import classification_report ,confusion_matrix

# %%
print(classification_report(y_test,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87     10579
#            1       0.65      0.29      0.40      3436
#
#     accuracy                           0.79     14015
#    macro avg       0.73      0.62      0.63     14015
# weighted avg       0.77      0.79      0.75     14015

# %% [markdown]
# ## Building a Decision Tree Model

# %%
from sklearn import tree, metrics, model_selection, preprocessing
from sklearn import tree

# %%
X = data.loc[:, data.columns != 'income']  # independent variables
y = data.loc[:, data.columns == 'income']  # Target variable

# %%
# split data randomly into 70% training and 30% test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# train the decision tree
dtree = tree.DecisionTreeClassifier(criterion='gini',random_state=0,min_samples_leaf=10,max_depth=3)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=10, random_state=0)

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dtree,feature_names=X_train.columns, class_names=['0','1'],filled=True)

# %%
y_pred_prob = dtree.predict_proba(X_test)
y_pred_prob[24]
# Out:
# array([0.34520918, 0.65479082])

# %%
# use the model to make predictions with the test data
y_pred = dtree.predict(X_test)
y_pred[24]
# Out:
# 1

# %%
decision_tree_acc = accuracy_score(y_pred,y_test)*100
decision_tree_acc
# Out:
# 83.97431323581877

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90     11735
#            1       0.51      0.74      0.60      2280
#
#     accuracy                           0.84     14015
#    macro avg       0.72      0.80      0.75     14015
# weighted avg       0.87      0.84      0.85     14015

# %% [markdown]
# ## Building a Random Forest Model

# %%
X = data.loc[:, data.columns != 'income']  # independent variables
y = data.loc[:, data.columns == 'income']  # Target variable

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, random_state=0)

# %%
#Importing random forest classifier 
from sklearn.ensemble import RandomForestClassifier

# %%
#creating a random forest instance
clf = RandomForestClassifier(random_state=96,n_estimators=600)

# %%
#train the model
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=600, random_state=96)

# %%
#score on training data
clf.score(X_train,y_train)
# Out:
# 0.9998776721000642

# %%
#score on test data
clf.score(X_test,y_test)
# Out:
# 0.8594363182304674

# %%
accuracy_score(y_test,y_pred_class)
# Out:
# 0.7074562968248306

# %%
#looking at the feature importance
clf.feature_importances_
# Out:
# array([0.14888044, 0.03784076, 0.1737038 , 0.0326997 , 0.08800517,
#        0.07152327, 0.06565978, 0.1046144 , 0.0139123 , 0.01200469,
#        0.11383255, 0.03723468, 0.08436711, 0.01572135])

# %%
#feature importance against each variable
pd.Series(clf.feature_importances_, index=X_train.columns)
# Out:
# age                0.148880
# workclass          0.037841
# fnlwgt             0.173704
# education          0.032700
# educational-num    0.088005
# marital-status     0.071523
# occupation         0.065660
# relationship       0.104614
# race               0.013912
# gender             0.012005
# capital-gain       0.113833
# capital-loss       0.037235
# hours-per-week     0.084367
# native-country     0.015721
# dtype: float64

# %%
random_forest_acc = accuracy_score(y_test,y_pred)*100

# %%
random_forest_acc
# Out:
# 83.97431323581877

# %%
x = {'random forest' : random_forest_acc,'logistic regression': log_reg_acc,'decision tree' : decision_tree_acc}

# %%
x
# Out:
# {'random forest': 83.97431323581877,
#  'logistic regression': 78.6942561541206,
#  'decision tree': 83.97431323581877}

# %%
accuracy = pd.DataFrame.from_dict(x, orient='index',columns=['accuracy'])

# %%
accuracy
# Out:
#                       accuracy
# random forest        83.974313
# logistic regression  78.694256
# decision tree        83.974313
